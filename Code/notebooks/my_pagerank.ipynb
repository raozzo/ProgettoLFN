# %% [markdown]
# # My implentation of the pagerank

# %% [markdown]
# We import libraries

# %%
import networkx as nx
import numpy as np
import scipy.sparse as sp
import sys

# %%
try:
    import cugraph
    import cudf
    HAS_GPU = True
    print("trovata GPU")
except ImportError:
    HAS_GPU = False
    print("NO GPU")
# Out:
# NO GPU
